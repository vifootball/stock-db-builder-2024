# %%
import etf
import time
import random
import os
from utils import *

# %%
etf_list = etf.get_symbols()

# %% [markdown]
# # get etf profile

# %%
etf.get_etf_profile("lqd")
# Out:
# Successfully Processed: lqd
#   symbol   asset_class        category         region stock_exchange  \
# 0    LQD  Fixed Income  Corporate Bond  North America       NYSEARCA
#
#   fund_family                            index_tracked
# 0   BlackRock  iBoxx USD Liquid Investment Grade Index

# %%
for symbol in etf_list[2880:]:
    time.sleep(0.3)
    time.sleep(round(random.uniform(1.1, 2), 3))

    etf_profile = etf.get_etf_profile(symbol)
    if etf_profile is not None:
        os.makedirs('downloads/etf_profile/', exist_ok=True)
        etf_profile.to_csv(f'downloads/etf_profile/{symbol}_profile.csv', index=False)

    # print(etf_profile)

# %%
concat_csv_files_in_dir('downloads/etf_profile/').to_csv('downloads/etf_profiles.csv', index=False)
# Out:
# 100%|██████████| 3516/3516 [00:02<00:00, 1703.23it/s]

# %%
concat_csv_files_in_dir('downloads/etf_profile/')
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 925.47it/s]
#    symbol       asset_class                        category         region  \
# 0    AMTR            Equity      Energy Limited Partnership  North America
# 1    AGGH      Fixed Income                             NaN  North America
# 2    AMAX  Asset Allocation                             NaN            NaN
# 3    ALAI            Equity                             NaN  North America
# 4    AAXJ            Equity       Pacific/Asia ex-Japan Stk   Asia-Pacific
# ..    ...               ...                             ...            ...
# 95   APIE            Equity                             NaN         Global
# 96   AGNG            Equity                          Health         Global
# 97    AGQ         Commodity  Trading--Leveraged Commodities            NaN
# 98   ACSI            Equity                     Large Blend  North America
# 99   ACTV            Equity                     Small Value  North America
#
#    stock_exchange           fund_family  \
# 0        NYSEARCA                ETRACS
# 1        NYSEARCA              Simplify
# 2        NYSEARCA  Adaptive Investments
# 3        NYSEARCA                 Alger
# 4          NASDAQ             BlackRock
# ..            ...                   ...
# 95       NYSEARCA             Envestnet
# 96         NASDAQ              Global X
# 97       NYSEARCA             ProShares
# 98           BATS                 Tidal
# 99       NYSEARCA               Redwood
#
#                                       index_tracked
# 0                    Alerian Midstream Energy Index
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                MSCI AC Asia ex JP
# ..                                              ...
# 95                                              NaN
# 96            Indxx Aging Population Thematic Index
# 97                                 Bloomberg Silver
# 98  American Customer Satisfaction Investable Index
# 99                                              NaN
#
# [100 rows x 7 columns]

# %% [markdown]
# # get etf info

# %%
for symbol in etf_list[2700:]:
    time.sleep(0.2)
    time.sleep(round(random.uniform(0.2, 0.8), 3))

    etf_info = etf.get_etf_info(symbol)
    if etf_info is not None:
        os.makedirs('downloads/etf_info/', exist_ok=True)
        etf_info.to_csv(f'downloads/etf_info/{symbol}_info.csv', index=False)

# %%
concat_csv_files_in_dir('downloads/etf_info/').to_csv('downloads/etf_infos.csv', index=False)
# Out:
# 100%|██████████| 3516/3516 [00:02<00:00, 1614.30it/s]

# %% [markdown]
# # Merge

# %%
etf_master = pd.read_csv('etf_list/etf_list_240605_union.csv')
etf_master.rename(columns={"fund_name": "name"}, inplace=True)
cols = ['symbol', 'name']
etf_master = etf_master[cols]
etf_master.head()
# Out:
#   symbol                                            name
# 0    AAA  Alternative Access First Priority CLO Bond ETF
# 1   AAAU                 Goldman Sachs Physical Gold ETF
# 2   AADR             AdvisorShares Dorsey Wright ADR ETF
# 3   AAPB            GraniteShares 2x Long AAPL Daily ETF
# 4   AAPD          Direxion Daily AAPL Bear 1X Shares ETF

# %%
etf_profile = pd.read_csv('./downloads/etf_profiles.csv')
etf_profile.head()
# Out:
#   symbol       asset_class                    category         region  \
# 0   AMTR            Equity  Energy Limited Partnership  North America
# 1   AGGH      Fixed Income                         NaN  North America
# 2   BFOR            Equity               Mid-Cap Blend  North America
# 3   ASEA            Equity   Pacific/Asia ex-Japan Stk   Asia-Pacific
# 4   AMAX  Asset Allocation                         NaN            NaN
#
#   stock_exchange           fund_family                   index_tracked
# 0       NYSEARCA                ETRACS  Alerian Midstream Energy Index
# 1       NYSEARCA              Simplify                             NaN
# 2       NYSEARCA                  SS&C              Barron's 400 Index
# 3       NYSEARCA              Global X             FTSE/ASEAN 40 INDEX
# 4       NYSEARCA  Adaptive Investments                             NaN

# %%
etf_info = pd.read_csv('./downloads/etf_infos.csv')
etf_info.head()
# Out:
#   symbol        aum   nav  expense_ratio  shares_outstanding  dividend_yield  \
# 0   AFIF  104650000  8.76         0.0109          11450000.0          0.0622
# 1   AAPR   67370000   NaN         0.0079           2700000.0             NaN
# 2   ADFI   41490000  8.41         0.0175           4880000.0          0.0304
# 3   AAPY    1020000   NaN         0.0099                 NaN          0.0686
# 4   AAPX    4410000   NaN         0.0105            170000.0             NaN
#
#     inception                                        description  \
# 0  2018-09-18  The Anfield Universal Fixed Income ETF (AFIF) ...
# 1  2024-04-01  The Innovator Equity Defined Protection ETF — ...
# 2  2020-08-18  The Anfield Dynamic Fixed Income ETF (ADFI) is...
# 3  2023-10-27  The Kurv Yield Premium Strategy Apple (AAPL) E...
# 4  2024-01-11  The T-Rex 2X Long Apple Daily Target ETF (AAPX...
#
#    holdings_count  holdings_top10_percentage holdings_date
# 0             280                        NaN           NaN
# 1               0                        0.0    2024-06-08
# 2              10                        NaN           NaN
# 3               0                        0.0    2024-06-08
# 4               0                        0.0    2024-06-08

# %%
etf_master = etf_master.merge(etf_info, how='left', on='symbol')
etf_master = etf_master.merge(etf_profile, how='left', on='symbol')
etf_master.to_csv('./downloads/etf_masters.csv', index=False)

# %% [markdown]
# # holdings

# %%
etf_list = etf.get_symbols()

# %%
for symbol in etf_list[3050:]:
    time.sleep(0.2)
    time.sleep(round(random.uniform(0.2, 0.8), 3))

    etf_holdings = etf.get_etf_holdings(symbol)
    if etf_holdings is not None:
        os.makedirs('downloads/etf_holdings/', exist_ok=True)
        etf_holdings.to_csv(f'downloads/etf_holdings/{symbol}_holdings.csv', index=False)
